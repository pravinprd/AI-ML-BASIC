# %%
import nltk
from nltk.stem import PorterStemmer
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.corpus import stopwords
from nltk import stem
lemat = stem.WordNetLemmatizer()
ps = PorterStemmer()
stopword= set(stopwords.words('english'))
print(stopword)
for line in open('data_in.txt'):
    print("\n"+line)
    words=word_tokenize(line)
    for word in words:
      if(word not in stopword):
         print("STEMMING:{0}".format(ps.stem(word)))
         print("LEMMATIZATION:{0}".format(lemat.lemmatize(word)))
# Out:
# {'so', 'yours', "needn't", "shouldn't", 'until', 'does', 'hadn', 'my', 'will', "wasn't", 'o', 'as', "shan't", 'of', 'won', 'how', "it's", 'll', 'a', 'don', 'then', "should've", "wouldn't", 'am', "doesn't", 'those', 'and', 'up', 'whom', 'for', 'wouldn', 'during', 'did', 'has', 'his', 'about', "hasn't", 'no', 'hers', 'to', "you're", 'they', 'ma', 'if', 'out', 're', 'because', 'which', 'was', 'few', 'each', 'such', 'at', 'other', 'mightn', 'needn', "mightn't", 't', "you'd", 'ain', 'is', 'too', 'weren', 'very', 'while', 'them', 'yourselves', 'doing', 'below', 'couldn', 'himself', 'who', 'between', 'i', 'these', 'our', 'most', 'ours', 's', 'd', 'were', 'more', 'in', 'itself', 'have', 'hasn', 'he', 'yourself', 'or', 'what', 'herself', 'had', 'off', "won't", 'shouldn', 'm', 'him', 'it', 'but', 'me', 'why', 'just', 'haven', 'your', 'only', 'be', 'that', 'their', "didn't", "haven't", 'all', 'not', 'after', 'ourselves', 'y', 'you', 'we', "aren't", 'some', 'aren', 'own', 'with', 'myself', 'theirs', 'now', 'didn', 'before', "mustn't", 'been', 'through', "couldn't", 'any', 'by', 'wasn', 'her', "isn't", "don't", 'against', 'again', 'should', 'same', 'under', "she's", 'themselves', 'she', 'here', 'isn', 'shan', 'once', 'the', 'an', "weren't", 'both', "you've", 'down', 've', 'are', "that'll", 'further', 'from', 'there', 'this', 'on', "hadn't", 'having', 'than', 'doesn', 'above', 'where', 'being', "you'll", 'nor', 'can', 'over', 'into', 'its', 'when', 'do', 'mustn'}
#
# Hello there, how are you? Weather is awesome. Its raining here now.
#
# STEMMING:hello
# LEMMATIZATION:Hello
# STEMMING:,
# LEMMATIZATION:,
# STEMMING:?
# LEMMATIZATION:?
# STEMMING:weather
# LEMMATIZATION:Weather
# STEMMING:awesom
# LEMMATIZATION:awesome
# STEMMING:.
# LEMMATIZATION:.
# STEMMING:it
# LEMMATIZATION:Its
# STEMMING:rain
# LEMMATIZATION:raining
# STEMMING:.
# LEMMATIZATION:.
#
# Hello Mr. Raja, how are you? Weather is awesome. Its raining here now.
#
# STEMMING:hello
# LEMMATIZATION:Hello
# STEMMING:mr.
# LEMMATIZATION:Mr.
# STEMMING:raja
# LEMMATIZATION:Raja
# STEMMING:,
# LEMMATIZATION:,
# STEMMING:?
# LEMMATIZATION:?
# STEMMING:weather
# LEMMATIZATION:Weather
# STEMMING:awesom
# LEMMATIZATION:awesome
# STEMMING:.
# LEMMATIZATION:.
# STEMMING:it
# LEMMATIZATION:Its
# STEMMING:rain
# LEMMATIZATION:raining
# STEMMING:.
# LEMMATIZATION:.
#
# Hello Mr. Raja, how are you. Weather is bad. Its heavily raining here now.
#
# STEMMING:hello
# LEMMATIZATION:Hello
# STEMMING:mr.
# LEMMATIZATION:Mr.
# STEMMING:raja
# LEMMATIZATION:Raja
# STEMMING:,
# LEMMATIZATION:,
# STEMMING:.
# LEMMATIZATION:.
# STEMMING:weather
# LEMMATIZATION:Weather
# STEMMING:bad
# LEMMATIZATION:bad
# STEMMING:.
# LEMMATIZATION:.
# STEMMING:it
# LEMMATIZATION:Its
# STEMMING:heavili
# LEMMATIZATION:heavily
# STEMMING:rain
# LEMMATIZATION:raining
# STEMMING:.
# LEMMATIZATION:.
#
# NLP is great technique. It is nice to learn this technique.
#
# STEMMING:nlp
# LEMMATIZATION:NLP
# STEMMING:great
# LEMMATIZATION:great
# STEMMING:techniqu
# LEMMATIZATION:technique
# STEMMING:.
# LEMMATIZATION:.
# STEMMING:It
# LEMMATIZATION:It
# STEMMING:nice
# LEMMATIZATION:nice
# STEMMING:learn
# LEMMATIZATION:learn
# STEMMING:techniqu
# LEMMATIZATION:technique
# STEMMING:.
# LEMMATIZATION:.
#
# AI is making difference in this world now.  It would be helpful for betterment of human life. We need to make advantage of that.
#
# STEMMING:AI
# LEMMATIZATION:AI
# STEMMING:make
# LEMMATIZATION:making
# STEMMING:differ
# LEMMATIZATION:difference
# STEMMING:world
# LEMMATIZATION:world
# STEMMING:.
# LEMMATIZATION:.
# STEMMING:It
# LEMMATIZATION:It
# STEMMING:would
# LEMMATIZATION:would
# STEMMING:help
# LEMMATIZATION:helpful
# STEMMING:better
# LEMMATIZATION:betterment
# STEMMING:human
# LEMMATIZATION:human
# STEMMING:life
# LEMMATIZATION:life
# STEMMING:.
# LEMMATIZATION:.
# STEMMING:We
# LEMMATIZATION:We
# STEMMING:need
# LEMMATIZATION:need
# STEMMING:make
# LEMMATIZATION:make
# STEMMING:advantag
# LEMMATIZATION:advantage
# STEMMING:.
# LEMMATIZATION:.
